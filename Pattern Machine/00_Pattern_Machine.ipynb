# %% [markdown]
# <a href="https://colab.research.google.com/github/amolk/AGI-experiments/blob/master/Pattern%20Machine/00_Pattern_Machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## `Pattern Machine`
#
# **Aha!** Afferent connections represent inputs and lateral connections represent output
#
# **Aha!** Represent pattern as a collection of channels, each channel a tuple of x and precision(x).

# %% [markdown]
# Starting point is [this notebook](https://colab.research.google.com/drive/1lrouLxaVMxNwyOAXNa_Il9RFvDmTjedb#scrollTo=rIePSk-Yy83W).
#
# ![IMG_20200829_090303.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# This notebook is at level 4. Here we will experiment with (input,neighborhood) joint patterns. Claim is that neurons represent an (input,output) joint probability distribution.
#
# Here we will use two images for training. The first image will show two triangles.
#
# ![two triangles.png](data:image/png;base64,...)
#
# The second training image is a blank image.
#
# Here are the test images.
#
# 1. Missing triangle - will the model fill it in using lateral context?
#
# ![two triangles - one missing.png](data:image/png;base64,...)
#
# 2. Missing fill - will the model fill that in?
#
# ![two triangles - missing fill.png](data:image/png;base64,...)
#
# 3. Optical illusion - will the model complete the triangle?
#
# ![two triangles - illusion.png](data:image/png;base64,...)

# %% [markdown]
# Note that we are not concerned here with how difficult these problems are to solve - they are trivial with memorization of training data. We are interested in the mechanisms the system uses to solve these.

# %% [markdown]
# BUT FIRST, we will make the pattern machine
# - continuous, i.e. activation changes over time as decaying history of instantaneous activation
# - modular, i.e. connect up more flexibly,
# - use multi-patterns, i.e. pattern contains more than 1 weights tensor. This is to represent input and output jointly.
